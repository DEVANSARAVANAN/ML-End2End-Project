# %% [markdown]
# <a href="https://www.kaggle.com/code/devansaravanan/data-wrangling?scriptVersionId=137280342" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## IMPORT XML,CSV,JSON

# %%
# Read XML
path='/kaggle/input/updated/sample.xml'
import xml.etree.ElementTree as ET
tree=ET.parse(path)
root_node=tree.getroot()
print("Attribute are:",root_node.attrib)
print("Values are:",root_node.text)
# Out:
# Attribute are: {'name': 'dev'}
# Values are: 10

# %%
#Read CSV
import pandas as pd
path='/kaggle/input/csv-set/csv_sample.csv'
data=pd.read_csv(path,header=None)
df=pd.DataFrame(data=data)
df.columns=['sno','name','sec','dep']
# df.rename(columns = {0:'sno',1:'name',2:'sec',3:'dep'}, inplace = True)
df
# Out:
#    sno  name  sec  dep
# 0    1   dev    2   ds
# 1    2   raj    3   cs
# 2    3  siva    1  phy

# %%
#Read JSON File
import json
path="/kaggle/input/json-sorce/sample.json"
f = open(path)

# returns JSON object as
# a dictionary
data = json.load(f)

for i in data['batters']['batter']:
    print(i['id'])

f.close()
# data['batters']['batter'][0]["id"]
# Out:
# 1001
# 1002
# 1003
# 1004
